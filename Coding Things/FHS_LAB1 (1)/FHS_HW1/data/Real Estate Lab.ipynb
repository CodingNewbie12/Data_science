# %%
import numpy as np
import pandas as pd
import random

# %%
df_column = pd.read_csv('C:/Users/jackscal004/Downloads/Coding Things/FHS_LAB1 (1)/FHS_HW1/data/Real Estate Data - Week 2 copy.csv', index_col = 0, header=0)

# %%
df_column.head(5)
# Out:
#                     Type       Zoning Class  Lot Frontage  Lot Area Alley  \
# Id
# 1   2-STORY 1946 & NEWER  Resid Low Density          65.0      8450   NaN
# 2   1-STORY 1946 & NEWER  Resid Low Density          80.0      9600   NaN
# 3   2-STORY 1946 & NEWER  Resid Low Density          68.0     11250   NaN
# 4   2-STORY 1945 & OLDER  Resid Low Density          60.0      9550   NaN
# 5   2-STORY 1946 & NEWER  Resid Low Density          84.0     14260   NaN
#
#              Lot Shape Land Contour           Lot Config Land Slope  \
# Id
# 1              Regular        Level           Inside lot     Gentle
# 2              Regular        Level  Frontage on 2 sides     Gentle
# 3   Slightly irregular        Level           Inside lot     Gentle
# 4   Slightly irregular        Level           Corner lot     Gentle
# 5   Slightly irregular        Level  Frontage on 2 sides     Gentle
#
#              Nbhd  ... Open Porch Area Enclosed Porch Area  \
# Id                 ...
# ...

# %%
filename = 'C:/Users/jackscal004/Downloads/Coding Things/FHS_LAB1 (1)/FHS_HW1/data/Real Estate Data .csv'
n = sum(1 for line in open(filename)) - 1 #number of records in file (excludes header)
s = 1000
skip = sorted(random.sample(range(1,n+1),n-s))
df = pd.read_csv(filename, skiprows=skip)
df.sample()
# Out:
#        Id                  Type       Zoning Class  Lot Frontage  Lot Area  \
# 706  1033  2-STORY 1946 & NEWER  Resid Low Density           NaN     14541
#
#     Alley           Lot Shape Land Contour  Lot Config Land Slope  ...  \
# 706   NaN  Slightly irregular        Level  Corner lot     Gentle  ...
#
#     Open Porch Area Enclosed Porch Area 3 Season Porch Area Screen Porch Area  \
# 706              55                   0                   0                 0
#
#      Pool Area  Pool Qual     Fence                     Sale Type  \
# 706          0    No Pool  No Fence  Warranty Deed - Conventional
#
#                                       Sale Condition Sale Price
# 706  Abnormal Sale -  trade, foreclosure, short sale     310000
#
# [1 rows x 69 columns]

# %%
df.tail(2)
# Out:
#        Id                  Type       Zoning Class  Lot Frontage  Lot Area  \
# 998  1458  2-STORY 1945 & OLDER  Resid Low Density          66.0      9042
# 999  1459  1-STORY 1946 & NEWER  Resid Low Density          68.0      9717
#
#     Alley Lot Shape Land Contour  Lot Config Land Slope  ... Open Porch Area  \
# 998   NaN   Regular        Level  Inside lot     Gentle  ...              60
# 999   NaN   Regular        Level  Inside lot     Gentle  ...               0
#
#     Enclosed Porch Area 3 Season Porch Area Screen Porch Area  Pool Area  \
# 998                   0                   0                 0          0
# 999                 112                   0                 0          0
#
#      Pool Qual         Fence                     Sale Type Sale Condition  \
# 998    No Pool  Good Privacy  Warranty Deed - Conventional    Normal Sale
# 999    No Pool      No Fence  Warranty Deed - Conventional    Normal Sale
#
#     Sale Price
# 998     266500
# 999     142125
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 69 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        1000 non-null   int64
#  1   Type                      1000 non-null   object
#  2   Zoning Class              1000 non-null   object
#  3   Lot Frontage              825 non-null    float64
#  4   Lot Area                  1000 non-null   int64
#  5   Alley                     60 non-null     object
#  6   Lot Shape                 1000 non-null   object
#  7   Land Contour              1000 non-null   object
#  8   Lot Config                1000 non-null   object
#  9   Land Slope                1000 non-null   object
#  10  Nbhd                      1000 non-null   object
#  11  Location Condition        1000 non-null   object
#  12  Bldg Type                 1000 non-null   object
# ...

# %%
df=df.rename(columns = {'Type':'Dwelling Type', \
                        'Balance on Revolving Accounts':'Revolving Accounts'})
